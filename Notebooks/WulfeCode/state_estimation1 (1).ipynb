# %%
#Pseudo Code:

# Set random seed for reproducibility
import numpy as np
import random
import math
			
class GPS:
    def __init__(self, apogee, total_steps, accuracy_radius):
        """
        All units are in metric - SI(standard international)
        """
        self.apogee = apogee
        self.n_steps = total_steps
        self.accuracy_radius = 5
        self.path = None

    def _parabolic_path(self):
        """
        Populates the self.path variable.
        So that you can then simulate GPS output on it.
        """
        for t, coordinate in enumerate(self.path):
            coordinate[0] = t
            coordinate[1] = (-0.001) * (t - 2000)**2 + self.apogee
            coordinate[2] = 0.0
        return self.path

    def simulate_gps(self, current_time):
        """
        Simulates coordinates from the GPS output, when the rocket is on `self.path`.
        Args:
        - current_time: needs to be between [1, total_steps]
        """
        startX=(1 + random.gauss(0, self.accuracy_radius))
        startY=(1.5 + random.gauss(0, self.accuracy_radius))
        startZ=(1.75 + random.gauss(0, self.accuracy_radius))
        
        gps_coordinates=np.ones((current_time,3,1))
        Amatrix = np.array([[1.5, 0, 0], [0, 1.75, 0], [0, 0, 1.25]])
        for i in range(current_time):
            if i ==0:
                gps_coordinates[i][0]=startX
                gps_coordinates[i][1]=startY
                gps_coordinates[i][2]=startZ
            else:
                gps_coordinates[i]=Amatrix@gps_coordinates[i-1]
                gps_coordinates[i][0] += random.gauss(0, self.accuracy_radius)
                gps_coordinates[i][1] += random.gauss(0, self.accuracy_radius)
                gps_coordinates[i][2] += random.gauss(0, self.accuracy_radius)

        return gps_coordinates		




class ParticleFilter:

    def __init__(self, Amatrix, Xvector, N = None, GPSArray = None, GPS_accuracy_radius = None):
        self.particlesArray = np.ndarray([3,N])
        self.N = 10
        self.std_dev = 3
        self.noise_std = 1
        self.old_distances = np.zeros((1,self.N))
        self.new_distances = np.zeros((1,self.N))
        self.old_particles = np.zeros((self.N,3,1))
        self.particles_curr = np.zeros((self.N,3,1), dtype=float)
        self.weights = np.zeros((self.N,1))
        self.Amatrix = np.array([[1.5, 0, 0], [0, 1.75, 0], [0, 0, 1.25]])
            
        
        self.X_GPS_curr = np.array(GPSArray[0])
        self.X_GPS_old = np.array(GPSArray[0])
        #!!!! changed particle dimensions to just 3

    def initializeParticles(self,particleLength,currGPS,std_dev):
        for i in range(particleLength):
            rX = np.random.normal(loc=currGPS[0], scale=std_dev)
            rY = np.random.normal(loc=currGPS[1], scale=std_dev)
            rZ = np.random.normal(loc=currGPS[2], scale=std_dev)
            self.particles_curr[i,0] = currGPS[0] + rX
            self.particles_curr[i,1] = currGPS[1] + rY
            self.particles_curr[i,2] = currGPS[2] + rZ
            self.weights[i] = 1/self.N

        #initialize weights to 1/n

    def calculate_theta(self, prev_pos, current_pos, particle_pos):
        # Calculate direction vectors
        prev_vector = np.array(current_pos).flatten() - np.array(prev_pos).flatten()
        particle_vector = np.array(particle_pos).flatten() - np.array(current_pos).flatten()
        
        # Normalize the vectors
        prev_vector_norm = prev_vector / np.linalg.norm(prev_vector)
        particle_vector_norm = particle_vector / np.linalg.norm(particle_vector)
        
        # Calculate the dot product
        dot_product = np.dot(prev_vector_norm, particle_vector_norm)
        
        # Clip the dot product to avoid numerical errors outside the range [-1, 1]
        dot_product = np.clip(dot_product, -1.0, 1.0)
        
        # Calculate the angle in radians and ensure it's a scalar
        theta = np.arccos(dot_product)

        return float(theta)

    def calculate_weight(self,particle_pos, prev_pos, current_pos, sigma_d = 10.0, kappa=1.0):
        d = np.linalg.norm(particle_pos-current_pos)
        #weighted by distance and angle with gaussian distribution
        distance_weight = np.exp(-d**2 / (2*sigma_d**2))
        #TODO
        theta = self.calculate_theta(prev_pos, current_pos, particle_pos)
        angle_weight = np.exp(-theta/kappa)

        return distance_weight * angle_weight
    
    def calculate_all_particle_weights(self,particles_curr, prev_pos, current_pos, sigma_d=10.0, kappa=1.0):

        for i in range(len(particles_curr)):
            self.weights[i] = self.calculate_weight(particles_curr[i], prev_pos, current_pos, 
                                sigma_d, kappa)
        self.weights += 1e-10  # Add a small constant to avoid underflow
        self.weights /= np.sum(self.weights)
        return self.weights


    def filterLowWeightParticles(self,currGPS,threshold=.95):

            cumSum = 0
            counter=0
            sortedIndeces = np.argsort(self.weights)
            for i in range(len(sortedIndeces)):
                if (1 - cumSum) <=threshold:
                    break
                cumSum += self.weights[sortedIndeces[i]]
                counter+=1

            dimensionDifference = len(self.particles_curr)-counter

            newParticleArray = np.ones((self.N,3,1))

            # We only want to copy N-counter particles (the ones we're keeping)
            for i in range(self.N - counter):
                newParticleArray[i+counter] = self.particles_curr[sortedIndeces[i+counter]]
            #from particlescurr of 0 to counter uniformally resample

            Vectoruniform_sample = np.random.uniform(low=-1, high=1, size=(counter,3,1))

            for i in range(counter):
                Vectoruniform_sample[i][0]+=currGPS[0]
                Vectoruniform_sample[i][1]+=currGPS[1]
                Vectoruniform_sample[i][2]+=currGPS[2]
                newParticleArray[self.N-i-1]=Vectoruniform_sample[i]

            weights_sum = sum(self.weights)
            newWeights = np.ones(self.N)

            # Only copy weights for the particles we're keeping (N-counter particles)
            for i in range(self.N - counter):
                newWeights[-(i+1)] = self.weights[sortedIndeces[-(i+1)]] / weights_sum
            #from newWeights of 0 to counter uniformally resample
            newWeights[:counter] = 1.0 / self.N  # or some other small constant value
# Normalize all weights to sum to 1
            newWeights = newWeights / np.sum(newWeights)
            self.weights = newWeights
            self.particles_curr=newParticleArray
            

    def progress_particles(self):
        # Motion model
        
        # Box-Muller transform for noise
        for i in range(len(self.particles_curr)):
            u1, u2 = np.random.uniform(0, 1, 2)
            r = np.sqrt(-2 * np.log(u1))
            theta = 2 * np.pi * u2
            
            # Generate two normal random variables
            z1 = r * np.cos(theta)
            z2 = r * np.sin(theta)
            z3 = np.random.normal(0, self.noise_std)  
            
            # Add noise to particle
            self.particles_curr[i] = self.Amatrix @ self.particles_curr[i] 
            self.particles_curr[i] += (np.array([z1, z2, z3]) * self.noise_std).reshape(3,1)


    def resampling(self):
        samplingThreshold = 2 * len(self.particles_curr) / 3
        print(f"Sampling threshold: {samplingThreshold}")

        # Initialize the cumulative distribution function (CDF)
        cdfArray = np.zeros(len(self.particles_curr))
        
        # Compute the cumulative sum of the weights
        for i in range(len(self.particles_curr)):
            cdfArray[i] = self.weights[i] + (cdfArray[i - 1] if i > 0 else 0)

        # Print the sum of squared weights (for debugging purpose)
        squaredWeights = np.sum(self.weights ** 2) / len(self.particles_curr)
        print(f"Squared weights: {squaredWeights}")
        
        if samplingThreshold > squaredWeights:
            rng = np.random.default_rng()  # Initialize the random number generator

            #TODO change resampled data to of self.N
            resampled_data = rng.uniform(low=0.0, high=1.0, size=int(self.N))
            print("Resampled data:", resampled_data)
            
            # Use np.searchsorted to get the indices of the resampled particles
            indices = np.searchsorted(cdfArray, resampled_data)
            print("Resampling indices:", indices)
            
            # Initialize new particles array with the correct size
            new_particles = np.zeros((len(resampled_data), 3, 1))

            # Assign resampled particles
            print("Selected resampled particles (before noise):")
            for i in range(len(resampled_data)):
                # Ensure the index is within bounds
                index = indices[i]  # Use modulo to wrap around if needed
                new_particles[i] = self.particles_curr[index]
                print(f"Resampled particle {i}: {new_particles[i]}")

            # Add noise to resampled particles
            for i in range(len(new_particles)):
                rX = np.random.normal(loc=new_particles[i][0], scale=self.std_dev)
                rY = np.random.normal(loc=new_particles[i][1], scale=self.std_dev)
                rZ = np.random.normal(loc=new_particles[i][2], scale=self.std_dev)
                
                
                # Update the particles with noise
                new_particles[i][0] += rX
                new_particles[i][1] += rY
                new_particles[i][2] += rZ
                print(f"Updated particle {i}: {new_particles[i]}")

            # Update the particles with the resampled and noise-modified particles
            self.particles_curr = new_particles
            print("Final particles after resampling and noise addition:")
            for i in range(len(self.particles_curr)):
                print(f"Particle {i}: {self.particles_curr[i]}")
def main():
    random.seed(42)
    counter = 0
    currGPS = GPS(4000,100,100)

    gps_coordinates = currGPS.simulate_gps(100)
    # print("hello", len(gps_coordinates))
    # for i in range(len(gps_coordinates)):
    #     print(gps_coordinates[i])

    Amatrix = np.array([[1.5, 0, 0], [0, 1.75, 0], [0, 0, 1.25]])
    stateVector = np.ones((3,1))
    currParticleFilter = ParticleFilter(Amatrix=Amatrix,Xvector=stateVector,N=1000,GPSArray=gps_coordinates,GPS_accuracy_radius=3)
    print("same shit")

    for i in range(20):
        print(f"we are at time step {i}")
        if i==0:
            currParticleFilter.initializeParticles(10,gps_coordinates[0],std_dev=3)
            print(f"entered initalize particles at time step {i}")
        else:
            currParticleFilter.progress_particles()
            print(f"entered progress particles at time step {i}")
            print(f"weight length {len(currParticleFilter.weights)}")
            print(f"particle length {len(currParticleFilter.particles_curr)}")
            currParticleFilter.calculate_all_particle_weights(currParticleFilter.particles_curr, gps_coordinates[i-1], gps_coordinates[i])
            print(f"entered calculateWeights particles at time step {i}")
            print(f"weight length {len(currParticleFilter.weights)}")
            print(f"particle length {len(currParticleFilter.particles_curr)}")
            currParticleFilter.resampling()
            print(f"entered reSampling particles at time step {i}")
            print(f"weight length {len(currParticleFilter.weights)}")
            print(f"particle length {len(currParticleFilter.particles_curr)}")
            currParticleFilter.filterLowWeightParticles(currGPS=gps_coordinates[i])
            print(f"entered filterParticles at time step {i}")
            print(f"weight length {len(currParticleFilter.weights)}")
            print(f"particle length {len(currParticleFilter.particles_curr)}")
#problems that may pop up in particle filter, resampling should repopulate the particles with of N length not a dependent length of the current particle array
        #initalize particles should be a uniform distribution, not a normal distribution around GPS
        #problem{1} resampling

if __name__=="__main__":
    main()
# Out:
# same shit
# we are at time step 0
# entered initalize particles at time step 0
# we are at time step 1
# entered progress particles at time step 1
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 1
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.01296072346622991
# Resampled data: [0.60941739 0.52541493 0.45323354 0.22086552 0.26452388 0.75669891
#  0.21366244 0.39628319 0.87104379 0.97795385]
# Resampling indices: [5 5 4 3 3 7 3 4 7 9]
# Selected resampled particles (before noise):
# Resampled particle 0: [[ 6.25819063]
#  [ 3.70743859]
#  [-0.29713331]]
# Resampled particle 1: [[ 6.25819063]
#  [ 3.70743859]
#  [-0.29713331]]
# Resampled particle 2: [[ 6.96265338]
#  [ 4.7098326 ]
#  [-1.34867258]]
# Resampled particle 3: [[-5.00239742]
#  [ 7.27473887]
#  [-1.14742071]]
# Resampled particle 4: [[-5.00239742]
#  [ 7.27473887]
#  [-1.14742071]]
# Resampled particle 5: [[ 7.50490753]
#  [ 2.7155136 ]
#  [-0.50933399]]
# Resampled particle 6: [[-5.00239742]
#  [ 7.27473887]
#  [-1.14742071]]
# Resampled particle 7: [[ 6.96265338]
#  [ 4.7098326 ]
#  [-1.34867258]]
# Resampled particle 8: [[ 7.50490753]
#  [ 2.7155136 ]
#  [-0.50933399]]
# Resampled particle 9: [[6.81866846]
#  [6.80233654]
#  [7.33289484]]
# Updated particle 0: [[12.36608967]
#  [ 9.85331242]
#  [-1.60766068]]
# Updated particle 1: [[ 9.27203894]
#  [ 8.53452945]
#  [-3.6881172 ]]
# Updated particle 2: [[12.03934034]
#  [ 9.78326861]
#  [-0.61712704]]
# Updated particle 3: [[-11.14010452]
#  [ 12.98989025]
#  [  0.52594541]]
# Updated particle 4: [[-7.01817877]
#  [12.54630136]
#  [-2.44309696]]
# Updated particle 5: [[10.71450614]
#  [ 4.62418966]
#  [ 3.26782451]]
# Updated particle 6: [[-8.523665  ]
#  [11.75195803]
#  [ 0.02132833]]
# Updated particle 7: [[13.50825062]
#  [11.8199    ]
#  [-4.38882587]]
# Updated particle 8: [[16.12942479]
#  [ 8.70101003]
#  [-2.91899009]]
# Updated particle 9: [[14.98657694]
#  [16.44199786]
#  [15.92612042]]
# Final particles after resampling and noise addition:
# Particle 0: [[12.36608967]
#  [ 9.85331242]
#  [-1.60766068]]
# Particle 1: [[ 9.27203894]
#  [ 8.53452945]
#  [-3.6881172 ]]
# Particle 2: [[12.03934034]
#  [ 9.78326861]
#  [-0.61712704]]
# Particle 3: [[-11.14010452]
#  [ 12.98989025]
#  [  0.52594541]]
# Particle 4: [[-7.01817877]
#  [12.54630136]
#  [-2.44309696]]
# Particle 5: [[10.71450614]
#  [ 4.62418966]
#  [ 3.26782451]]
# Particle 6: [[-8.523665  ]
#  [11.75195803]
#  [ 0.02132833]]
# Particle 7: [[13.50825062]
#  [11.8199    ]
#  [-4.38882587]]
# Particle 8: [[16.12942479]
#  [ 8.70101003]
#  [-2.91899009]]
# Particle 9: [[14.98657694]
#  [16.44199786]
#  [15.92612042]]
# entered reSampling particles at time step 1
# weight length 10
# particle length 10
# entered filterParticles at time step 1
# weight length 10
# particle length 10
# we are at time step 2
# entered progress particles at time step 2
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 2
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.02208728817993164
# Resampled data: [0.30155088 0.3461813  0.16685014 0.64141439 0.42857053 0.89964101
#  0.43017526 0.43304791 0.50691447 0.4254313 ]
# Resampling indices: [4 4 2 9 6 9 6 6 8 6]
# Selected resampled particles (before noise):
# Resampled particle 0: [[17.66116445]
#  [17.25966559]
#  [-2.64360404]]
# Resampled particle 1: [[17.66116445]
#  [17.25966559]
#  [-2.64360404]]
# Resampled particle 2: [[17.34288779]
#  [18.10120334]
#  [-1.87038329]]
# Resampled particle 3: [[ 6.72565136]
#  [ 2.54564902]
#  [-8.63115928]]
# Resampled particle 4: [[20.31321366]
#  [17.78661746]
#  [-0.50008743]]
# Resampled particle 5: [[ 6.72565136]
#  [ 2.54564902]
#  [-8.63115928]]
# Resampled particle 6: [[20.31321366]
#  [17.78661746]
#  [-0.50008743]]
# Resampled particle 7: [[20.31321366]
#  [17.78661746]
#  [-0.50008743]]
# Resampled particle 8: [[19.25044604]
#  [16.09073536]
#  [-1.45987676]]
# Resampled particle 9: [[20.31321366]
#  [17.78661746]
#  [-0.50008743]]
# Updated particle 0: [[34.9928952 ]
#  [29.78099319]
#  [-8.58797425]]
# Updated particle 1: [[ 36.53671916]
#  [ 33.98329626]
#  [-12.25019787]]
# Updated particle 2: [[35.9964743 ]
#  [38.45199412]
#  [-5.62554915]]
# Updated particle 3: [[ 11.33208522]
#  [ 10.20141722]
#  [-17.35920447]]
# Updated particle 4: [[43.13238753]
#  [41.49864367]
#  [-1.02905784]]
# Updated particle 5: [[ 14.54801265]
#  [  7.82518911]
#  [-19.03578766]]
# Updated particle 6: [[42.93997601]
#  [29.2242807 ]
#  [-4.13499062]]
# Updated particle 7: [[42.06895004]
#  [37.54397565]
#  [ 0.65831738]]
# Updated particle 8: [[42.42665781]
#  [31.75269194]
#  [-5.69076102]]
# Updated particle 9: [[37.3478362 ]
#  [30.71900418]
#  [ 2.98521055]]
# Final particles after resampling and noise addition:
# Particle 0: [[34.9928952 ]
#  [29.78099319]
#  [-8.58797425]]
# Particle 1: [[ 36.53671916]
#  [ 33.98329626]
#  [-12.25019787]]
# Particle 2: [[35.9964743 ]
#  [38.45199412]
#  [-5.62554915]]
# Particle 3: [[ 11.33208522]
#  [ 10.20141722]
#  [-17.35920447]]
# Particle 4: [[43.13238753]
#  [41.49864367]
#  [-1.02905784]]
# Particle 5: [[ 14.54801265]
#  [  7.82518911]
#  [-19.03578766]]
# Particle 6: [[42.93997601]
#  [29.2242807 ]
#  [-4.13499062]]
# Particle 7: [[42.06895004]
#  [37.54397565]
#  [ 0.65831738]]
# Particle 8: [[42.42665781]
#  [31.75269194]
#  [-5.69076102]]
# Particle 9: [[37.3478362 ]
#  [30.71900418]
#  [ 2.98521055]]
# entered reSampling particles at time step 2
# weight length 10
# particle length 10
# entered filterParticles at time step 2
# weight length 10
# particle length 10
# we are at time step 3
# entered progress particles at time step 3
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 3
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.02511352379925278
# Resampled data: [0.12459644 0.37740019 0.51087211 0.76580556 0.16090347 0.70237173
#  0.63934053 0.25509565 0.53764653 0.17645949]
# Resampling indices: [0 1 8 9 0 9 8 1 8 0]
# Selected resampled particles (before noise):
# Resampled particle 0: [[ 0.52908597]
#  [ 1.99435654]
#  [-1.22431416]]
# Resampled particle 1: [[1.55802263]
#  [1.25974052]
#  [1.03956339]]
# Resampled particle 2: [[  9.44942144]
#  [  1.16604263]
#  [-11.55399043]]
# Resampled particle 3: [[ 12.82736232]
#  [  0.04750795]
#  [-11.39315848]]
# Resampled particle 4: [[ 0.52908597]
#  [ 1.99435654]
#  [-1.22431416]]
# Resampled particle 5: [[ 12.82736232]
#  [  0.04750795]
#  [-11.39315848]]
# Resampled particle 6: [[  9.44942144]
#  [  1.16604263]
#  [-11.55399043]]
# Resampled particle 7: [[1.55802263]
#  [1.25974052]
#  [1.03956339]]
# Resampled particle 8: [[  9.44942144]
#  [  1.16604263]
#  [-11.55399043]]
# Resampled particle 9: [[ 0.52908597]
#  [ 1.99435654]
#  [-1.22431416]]
# Updated particle 0: [[ 1.16000784]
#  [ 8.97331903]
#  [-0.72566995]]
# Updated particle 1: [[ 4.46505006]
#  [ 2.01921673]
#  [-0.1172081 ]]
# Updated particle 2: [[ 15.82743904]
#  [  3.41779203]
#  [-27.71604875]]
# Updated particle 3: [[ 19.93219357]
#  [  0.84131572]
#  [-23.43378287]]
# Updated particle 4: [[ 2.52411321]
#  [ 1.68388191]
#  [-1.68891591]]
# Updated particle 5: [[ 25.50456494]
#  [ -2.87693012]
#  [-21.62730306]]
# Updated particle 6: [[ 18.87663785]
#  [ -0.1036071 ]
#  [-21.92041216]]
# Updated particle 7: [[5.85613987]
#  [0.97380282]
#  [3.45272845]]
# Updated particle 8: [[  9.53423313]
#  [  1.42560744]
#  [-22.9911845 ]]
# Updated particle 9: [[ 0.02681882]
#  [-4.37215125]
#  [-1.40471815]]
# Final particles after resampling and noise addition:
# Particle 0: [[ 1.16000784]
#  [ 8.97331903]
#  [-0.72566995]]
# Particle 1: [[ 4.46505006]
#  [ 2.01921673]
#  [-0.1172081 ]]
# Particle 2: [[ 15.82743904]
#  [  3.41779203]
#  [-27.71604875]]
# Particle 3: [[ 19.93219357]
#  [  0.84131572]
#  [-23.43378287]]
# Particle 4: [[ 2.52411321]
#  [ 1.68388191]
#  [-1.68891591]]
# Particle 5: [[ 25.50456494]
#  [ -2.87693012]
#  [-21.62730306]]
# Particle 6: [[ 18.87663785]
#  [ -0.1036071 ]
#  [-21.92041216]]
# Particle 7: [[5.85613987]
#  [0.97380282]
#  [3.45272845]]
# Particle 8: [[  9.53423313]
#  [  1.42560744]
#  [-22.9911845 ]]
# Particle 9: [[ 0.02681882]
#  [-4.37215125]
#  [-1.40471815]]
# entered reSampling particles at time step 3
# weight length 10
# particle length 10
# entered filterParticles at time step 3
# weight length 10
# particle length 10
# we are at time step 4
# entered progress particles at time step 4
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 4
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.014615253151760908
# Resampled data: [0.23672554 0.11108301 0.35208713 0.65344082 0.09506008 0.53974396
#  0.25946324 0.21090391 0.26382197 0.8396266 ]
# Resampling indices: [4 3 5 7 3 7 4 4 4 8]
# Selected resampled particles (before noise):
# Resampled particle 0: [[17.27950209]
#  [-1.54329004]
#  [-5.28610104]]
# Resampled particle 1: [[18.56229423]
#  [ 0.87423832]
#  [-5.22105018]]
# Resampled particle 2: [[18.2329846 ]
#  [ 0.69230697]
#  [-8.15546239]]
# Resampled particle 3: [[20.40094157]
#  [ 1.88742687]
#  [-4.66154123]]
# Resampled particle 4: [[18.56229423]
#  [ 0.87423832]
#  [-5.22105018]]
# Resampled particle 5: [[20.40094157]
#  [ 1.88742687]
#  [-4.66154123]]
# Resampled particle 6: [[17.27950209]
#  [-1.54329004]
#  [-5.28610104]]
# Resampled particle 7: [[17.27950209]
#  [-1.54329004]
#  [-5.28610104]]
# Resampled particle 8: [[17.27950209]
#  [-1.54329004]
#  [-5.28610104]]
# Resampled particle 9: [[16.97493655]
#  [ 1.08223911]
#  [-4.10945843]]
# Updated particle 0: [[ 38.03388603]
#  [ -3.92914005]
#  [-17.16164475]]
# Updated particle 1: [[ 39.96392156]
#  [  5.69446015]
#  [-13.88221673]]
# Updated particle 2: [[ 34.08574272]
#  [  3.38327138]
#  [-14.21397467]]
# Updated particle 3: [[ 42.77662581]
#  [  5.48400233]
#  [-10.59781853]]
# Updated particle 4: [[ 39.5542591 ]
#  [ -1.58582265]
#  [-12.16530557]]
# Updated particle 5: [[ 37.24047017]
#  [  5.52264546]
#  [-11.0876584 ]]
# Updated particle 6: [[ 33.06437905]
#  [  0.56275876]
#  [-16.81687966]]
# Updated particle 7: [[ 34.16426599]
#  [ -5.30293321]
#  [-12.11855857]]
# Updated particle 8: [[30.7465883 ]
#  [-1.02925521]
#  [-9.44004094]]
# Updated particle 9: [[31.02020166]
#  [-3.20875269]
#  [-5.34253846]]
# Final particles after resampling and noise addition:
# Particle 0: [[ 38.03388603]
#  [ -3.92914005]
#  [-17.16164475]]
# Particle 1: [[ 39.96392156]
#  [  5.69446015]
#  [-13.88221673]]
# Particle 2: [[ 34.08574272]
#  [  3.38327138]
#  [-14.21397467]]
# Particle 3: [[ 42.77662581]
#  [  5.48400233]
#  [-10.59781853]]
# Particle 4: [[ 39.5542591 ]
#  [ -1.58582265]
#  [-12.16530557]]
# Particle 5: [[ 37.24047017]
#  [  5.52264546]
#  [-11.0876584 ]]
# Particle 6: [[ 33.06437905]
#  [  0.56275876]
#  [-16.81687966]]
# Particle 7: [[ 34.16426599]
#  [ -5.30293321]
#  [-12.11855857]]
# Particle 8: [[30.7465883 ]
#  [-1.02925521]
#  [-9.44004094]]
# Particle 9: [[31.02020166]
#  [-3.20875269]
#  [-5.34253846]]
# entered reSampling particles at time step 4
# weight length 10
# particle length 10
# entered filterParticles at time step 4
# weight length 10
# particle length 10
# we are at time step 5
# entered progress particles at time step 5
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 5
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.020399482334119846
# Resampled data: [0.28425451 0.45872821 0.26119282 0.52595589 0.26312839 0.17636454
#  0.02930335 0.45357832 0.58667822 0.96468003]
# Resampling indices: [6 7 6 7 6 6 4 7 8 9]
# Selected resampled particles (before noise):
# Resampled particle 0: [[ 31.12193261]
#  [  3.58695764]
#  [-12.46353621]]
# Resampled particle 1: [[ 30.89310523]
#  [  1.92869153]
#  [-11.01729021]]
# Resampled particle 2: [[ 31.12193261]
#  [  3.58695764]
#  [-12.46353621]]
# Resampled particle 3: [[ 30.89310523]
#  [  1.92869153]
#  [-11.01729021]]
# Resampled particle 4: [[ 31.12193261]
#  [  3.58695764]
#  [-12.46353621]]
# Resampled particle 5: [[ 31.12193261]
#  [  3.58695764]
#  [-12.46353621]]
# Resampled particle 6: [[ 45.7095147 ]
#  [ -0.30138801]
#  [-12.92588039]]
# Resampled particle 7: [[ 30.89310523]
#  [  1.92869153]
#  [-11.01729021]]
# Resampled particle 8: [[ 32.11577104]
#  [  3.9192536 ]
#  [-10.19940234]]
# Resampled particle 9: [[ 33.08107275]
#  [  1.18983825]
#  [-12.77035221]]
# Updated particle 0: [[ 60.54498984]
#  [  5.91808107]
#  [-28.68578136]]
# Updated particle 1: [[ 65.21709432]
#  [  5.12165047]
#  [-25.13876142]]
# Updated particle 2: [[ 60.5724664 ]
#  [  7.00477085]
#  [-23.42204433]]
# Updated particle 3: [[ 62.1795897 ]
#  [  5.37699188]
#  [-20.54413605]]
# Updated particle 4: [[ 56.28480032]
#  [  4.06316471]
#  [-27.24423958]]
# Updated particle 5: [[ 61.34393312]
#  [  9.91196472]
#  [-21.4435828 ]]
# Updated particle 6: [[ 93.42329874]
#  [ -5.20648039]
#  [-19.80021103]]
# Updated particle 7: [[ 59.31912789]
#  [ -0.59359198]
#  [-25.40454171]]
# Updated particle 8: [[ 66.45189762]
#  [ 13.80266302]
#  [-26.4288275 ]]
# Updated particle 9: [[ 61.79105104]
#  [  3.19811237]
#  [-23.1743819 ]]
# Final particles after resampling and noise addition:
# Particle 0: [[ 60.54498984]
#  [  5.91808107]
#  [-28.68578136]]
# Particle 1: [[ 65.21709432]
#  [  5.12165047]
#  [-25.13876142]]
# Particle 2: [[ 60.5724664 ]
#  [  7.00477085]
#  [-23.42204433]]
# Particle 3: [[ 62.1795897 ]
#  [  5.37699188]
#  [-20.54413605]]
# Particle 4: [[ 56.28480032]
#  [  4.06316471]
#  [-27.24423958]]
# Particle 5: [[ 61.34393312]
#  [  9.91196472]
#  [-21.4435828 ]]
# Particle 6: [[ 93.42329874]
#  [ -5.20648039]
#  [-19.80021103]]
# Particle 7: [[ 59.31912789]
#  [ -0.59359198]
#  [-25.40454171]]
# Particle 8: [[ 66.45189762]
#  [ 13.80266302]
#  [-26.4288275 ]]
# Particle 9: [[ 61.79105104]
#  [  3.19811237]
#  [-23.1743819 ]]
# entered reSampling particles at time step 5
# weight length 10
# particle length 10
# entered filterParticles at time step 5
# weight length 10
# particle length 10
# we are at time step 6
# entered progress particles at time step 6
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 6
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.021722170717276466
# Resampled data: [0.94898811 0.39747989 0.98543197 0.03368692 0.05241628 0.72391375
#  0.59813646 0.27288646 0.47963106 0.84751011]
# Resampling indices: [9 6 9 5 5 8 7 6 7 9]
# Selected resampled particles (before noise):
# Resampled particle 0: [[41.50942458]
#  [ 4.10326421]
#  [-7.11007246]]
# Resampled particle 1: [[41.88141495]
#  [ 7.42704172]
#  [-8.10492574]]
# Resampled particle 2: [[41.50942458]
#  [ 4.10326421]
#  [-7.11007246]]
# Resampled particle 3: [[40.08705579]
#  [ 4.76541896]
#  [-5.94286389]]
# Resampled particle 4: [[40.08705579]
#  [ 4.76541896]
#  [-5.94286389]]
# Resampled particle 5: [[39.12554668]
#  [ 6.21021964]
#  [-5.31596608]]
# Resampled particle 6: [[40.08137626]
#  [ 4.05822415]
#  [-6.46111255]]
# Resampled particle 7: [[41.88141495]
#  [ 7.42704172]
#  [-8.10492574]]
# Resampled particle 8: [[40.08137626]
#  [ 4.05822415]
#  [-6.46111255]]
# Resampled particle 9: [[41.50942458]
#  [ 4.10326421]
#  [-7.11007246]]
# Updated particle 0: [[ 79.24669952]
#  [ 12.89681271]
#  [-13.91971071]]
# Updated particle 1: [[ 78.17717354]
#  [ 17.54520591]
#  [-13.58319717]]
# Updated particle 2: [[ 82.4476114 ]
#  [  9.17863331]
#  [-11.5766176 ]]
# Updated particle 3: [[ 81.50054222]
#  [ 12.5241471 ]
#  [-15.36821806]]
# Updated particle 4: [[ 79.64304244]
#  [ 11.14475617]
#  [-12.18839228]]
# Updated particle 5: [[ 75.41167782]
#  [ 14.34713134]
#  [-15.04898887]]
# Updated particle 6: [[ 80.37238192]
#  [ 10.55082219]
#  [-11.19118989]]
# Updated particle 7: [[ 88.50785439]
#  [ 14.82731777]
#  [-18.58403847]]
# Updated particle 8: [[ 78.67575369]
#  [ 10.65885916]
#  [-16.08628807]]
# Updated particle 9: [[ 84.53058377]
#  [  7.92653476]
#  [-14.0708115 ]]
# Final particles after resampling and noise addition:
# Particle 0: [[ 79.24669952]
#  [ 12.89681271]
#  [-13.91971071]]
# Particle 1: [[ 78.17717354]
#  [ 17.54520591]
#  [-13.58319717]]
# Particle 2: [[ 82.4476114 ]
#  [  9.17863331]
#  [-11.5766176 ]]
# Particle 3: [[ 81.50054222]
#  [ 12.5241471 ]
#  [-15.36821806]]
# Particle 4: [[ 79.64304244]
#  [ 11.14475617]
#  [-12.18839228]]
# Particle 5: [[ 75.41167782]
#  [ 14.34713134]
#  [-15.04898887]]
# Particle 6: [[ 80.37238192]
#  [ 10.55082219]
#  [-11.19118989]]
# Particle 7: [[ 88.50785439]
#  [ 14.82731777]
#  [-18.58403847]]
# Particle 8: [[ 78.67575369]
#  [ 10.65885916]
#  [-16.08628807]]
# Particle 9: [[ 84.53058377]
#  [  7.92653476]
#  [-14.0708115 ]]
# entered reSampling particles at time step 6
# weight length 10
# particle length 10
# entered filterParticles at time step 6
# weight length 10
# particle length 10
# we are at time step 7
# entered progress particles at time step 7
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 7
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.017045347497243592
# Resampled data: [0.33963396 0.09183947 0.36288919 0.63881325 0.78861873 0.51360846
#  0.05757515 0.9776496  0.41602693 0.97616781]
# Resampling indices: [6 4 6 8 8 7 4 9 6 9]
# Selected resampled particles (before noise):
# Resampled particle 0: [[59.52302657]
#  [ 6.24886948]
#  [-5.54320681]]
# Resampled particle 1: [[60.54529075]
#  [10.32759227]
#  [-7.28253761]]
# Resampled particle 2: [[59.52302657]
#  [ 6.24886948]
#  [-5.54320681]]
# Resampled particle 3: [[57.65624843]
#  [ 7.11601813]
#  [-5.09291582]]
# Resampled particle 4: [[57.65624843]
#  [ 7.11601813]
#  [-5.09291582]]
# Resampled particle 5: [[59.65557688]
#  [ 6.07299325]
#  [-7.34471855]]
# Resampled particle 6: [[60.54529075]
#  [10.32759227]
#  [-7.28253761]]
# Resampled particle 7: [[59.13869405]
#  [ 9.89306392]
#  [-5.84032483]]
# Resampled particle 8: [[59.52302657]
#  [ 6.24886948]
#  [-5.54320681]]
# Resampled particle 9: [[59.13869405]
#  [ 9.89306392]
#  [-5.84032483]]
# Updated particle 0: [[117.51848094]
#  [  9.71588406]
#  [ -7.07993585]]
# Updated particle 1: [[124.78866228]
#  [ 21.88884304]
#  [-17.83968021]]
# Updated particle 2: [[123.56841555]
#  [ 16.47728288]
#  [ -9.41446104]]
# Updated particle 3: [[117.65589881]
#  [ 10.39113555]
#  [-11.82448589]]
# Updated particle 4: [[120.01107765]
#  [ 14.51031479]
#  [-10.81589246]]
# Updated particle 5: [[117.85149616]
#  [ 12.89239455]
#  [-10.75117144]]
# Updated particle 6: [[123.95011708]
#  [ 18.10342229]
#  [-15.0592402 ]]
# Updated particle 7: [[123.69669874]
#  [ 22.38792913]
#  [ -8.21081999]]
# Updated particle 8: [[115.55926844]
#  [ 11.7930303 ]
#  [ -9.97395729]]
# Updated particle 9: [[117.76713832]
#  [ 22.61399878]
#  [ -8.36353492]]
# Final particles after resampling and noise addition:
# Particle 0: [[117.51848094]
#  [  9.71588406]
#  [ -7.07993585]]
# Particle 1: [[124.78866228]
#  [ 21.88884304]
#  [-17.83968021]]
# Particle 2: [[123.56841555]
#  [ 16.47728288]
#  [ -9.41446104]]
# Particle 3: [[117.65589881]
#  [ 10.39113555]
#  [-11.82448589]]
# Particle 4: [[120.01107765]
#  [ 14.51031479]
#  [-10.81589246]]
# Particle 5: [[117.85149616]
#  [ 12.89239455]
#  [-10.75117144]]
# Particle 6: [[123.95011708]
#  [ 18.10342229]
#  [-15.0592402 ]]
# Particle 7: [[123.69669874]
#  [ 22.38792913]
#  [ -8.21081999]]
# Particle 8: [[115.55926844]
#  [ 11.7930303 ]
#  [ -9.97395729]]
# Particle 9: [[117.76713832]
#  [ 22.61399878]
#  [ -8.36353492]]
# entered reSampling particles at time step 7
# weight length 10
# particle length 10
# entered filterParticles at time step 7
# weight length 10
# particle length 10
# we are at time step 8
# entered progress particles at time step 8
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 8
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.021317344141744778
# Resampled data: [0.92670124 0.21839941 0.95231069 0.23289403 0.25923876 0.8108609
#  0.92298211 0.11523006 0.91703427 0.55508952]
# Resampling indices: [9 5 9 6 6 8 9 5 9 7]
# Selected resampled particles (before noise):
# Resampled particle 0: [[80.99500899]
#  [11.92670032]
#  [-2.17507476]]
# Resampled particle 1: [[79.79355763]
#  [13.34550121]
#  [-4.86277804]]
# Resampled particle 2: [[80.99500899]
#  [11.92670032]
#  [-2.17507476]]
# Resampled particle 3: [[80.71345657]
#  [14.69807509]
#  [-5.63816963]]
# Resampled particle 4: [[80.71345657]
#  [14.69807509]
#  [-5.63816963]]
# Resampled particle 5: [[78.75231212]
#  [ 9.71964985]
#  [-5.97411997]]
# Resampled particle 6: [[80.99500899]
#  [11.92670032]
#  [-2.17507476]]
# Resampled particle 7: [[79.79355763]
#  [13.34550121]
#  [-4.86277804]]
# Resampled particle 8: [[80.99500899]
#  [11.92670032]
#  [-2.17507476]]
# Resampled particle 9: [[79.15039021]
#  [ 9.0816957 ]
#  [-1.12940773]]
# Updated particle 0: [[163.67421827]
#  [ 24.447555  ]
#  [ -5.67158376]]
# Updated particle 1: [[156.56137692]
#  [ 29.31270472]
#  [ -9.09000603]]
# Updated particle 2: [[162.08224485]
#  [ 18.67600546]
#  [ -7.37664738]]
# Updated particle 3: [[163.923416  ]
#  [ 35.75115248]
#  [-10.70998927]]
# Updated particle 4: [[160.65610949]
#  [ 31.39893693]
#  [-13.25676675]]
# Updated particle 5: [[160.4847514 ]
#  [ 16.82510382]
#  [-15.27813672]]
# Updated particle 6: [[161.0304584 ]
#  [ 22.68848319]
#  [ -5.30401846]]
# Updated particle 7: [[158.75194178]
#  [ 26.00320036]
#  [ -6.87573139]]
# Updated particle 8: [[160.63203937]
#  [ 21.25299381]
#  [ -1.43022057]]
# Updated particle 9: [[157.01452763]
#  [ 17.44354902]
#  [-11.13284692]]
# Final particles after resampling and noise addition:
# Particle 0: [[163.67421827]
#  [ 24.447555  ]
#  [ -5.67158376]]
# Particle 1: [[156.56137692]
#  [ 29.31270472]
#  [ -9.09000603]]
# Particle 2: [[162.08224485]
#  [ 18.67600546]
#  [ -7.37664738]]
# Particle 3: [[163.923416  ]
#  [ 35.75115248]
#  [-10.70998927]]
# Particle 4: [[160.65610949]
#  [ 31.39893693]
#  [-13.25676675]]
# Particle 5: [[160.4847514 ]
#  [ 16.82510382]
#  [-15.27813672]]
# Particle 6: [[161.0304584 ]
#  [ 22.68848319]
#  [ -5.30401846]]
# Particle 7: [[158.75194178]
#  [ 26.00320036]
#  [ -6.87573139]]
# Particle 8: [[160.63203937]
#  [ 21.25299381]
#  [ -1.43022057]]
# Particle 9: [[157.01452763]
#  [ 17.44354902]
#  [-11.13284692]]
# entered reSampling particles at time step 8
# weight length 10
# particle length 10
# entered filterParticles at time step 8
# weight length 10
# particle length 10
# we are at time step 9
# entered progress particles at time step 9
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 9
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.017891871280812866
# Resampled data: [0.89509143 0.09922428 0.64921561 0.27831075 0.48312683 0.53747049
#  0.16956241 0.94697859 0.51578014 0.82507862]
# Resampling indices: [9 4 7 5 6 7 5 9 6 9]
# Selected resampled particles (before noise):
# Resampled particle 0: [[128.25650845]
#  [ 18.35938549]
#  [ -4.26061241]]
# Resampled particle 1: [[126.35220203]
#  [ 19.1659446 ]
#  [ -6.44238515]]
# Resampled particle 2: [[126.02275183]
#  [ 17.58694575]
#  [ -1.86107391]]
# Resampled particle 3: [[128.57009382]
#  [ 19.75132924]
#  [ -2.57581193]]
# Resampled particle 4: [[125.81291351]
#  [ 17.95745836]
#  [ -1.5120932 ]]
# Resampled particle 5: [[126.02275183]
#  [ 17.58694575]
#  [ -1.86107391]]
# Resampled particle 6: [[128.57009382]
#  [ 19.75132924]
#  [ -2.57581193]]
# Resampled particle 7: [[128.25650845]
#  [ 18.35938549]
#  [ -4.26061241]]
# Resampled particle 8: [[125.81291351]
#  [ 17.95745836]
#  [ -1.5120932 ]]
# Resampled particle 9: [[128.25650845]
#  [ 18.35938549]
#  [ -4.26061241]]
# Updated particle 0: [[255.60934425]
#  [ 40.26986528]
#  [-11.68797425]]
# Updated particle 1: [[250.51804074]
#  [ 38.98629654]
#  [-10.53181877]]
# Updated particle 2: [[251.08230272]
#  [ 33.38724473]
#  [ -2.34661298]]
# Updated particle 3: [[260.69252436]
#  [ 40.16804255]
#  [  0.80773136]]
# Updated particle 4: [[252.91397868]
#  [ 38.6778216 ]
#  [ -4.13307065]]
# Updated particle 5: [[253.40375797]
#  [ 33.87603401]
#  [ -4.87486425]]
# Updated particle 6: [[259.19589163]
#  [ 49.12949291]
#  [ -4.27131829]]
# Updated particle 7: [[255.940325  ]
#  [ 33.3045476 ]
#  [  0.39725173]]
# Updated particle 8: [[248.33850096]
#  [ 34.18103847]
#  [ -2.98344859]]
# Updated particle 9: [[257.76543784]
#  [ 39.48663682]
#  [-11.57079099]]
# Final particles after resampling and noise addition:
# Particle 0: [[255.60934425]
#  [ 40.26986528]
#  [-11.68797425]]
# Particle 1: [[250.51804074]
#  [ 38.98629654]
#  [-10.53181877]]
# Particle 2: [[251.08230272]
#  [ 33.38724473]
#  [ -2.34661298]]
# Particle 3: [[260.69252436]
#  [ 40.16804255]
#  [  0.80773136]]
# Particle 4: [[252.91397868]
#  [ 38.6778216 ]
#  [ -4.13307065]]
# Particle 5: [[253.40375797]
#  [ 33.87603401]
#  [ -4.87486425]]
# Particle 6: [[259.19589163]
#  [ 49.12949291]
#  [ -4.27131829]]
# Particle 7: [[255.940325  ]
#  [ 33.3045476 ]
#  [  0.39725173]]
# Particle 8: [[248.33850096]
#  [ 34.18103847]
#  [ -2.98344859]]
# Particle 9: [[257.76543784]
#  [ 39.48663682]
#  [-11.57079099]]
# entered reSampling particles at time step 9
# weight length 10
# particle length 10
# entered filterParticles at time step 9
# weight length 10
# particle length 10
# we are at time step 10
# entered progress particles at time step 10
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 10
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.02032950896564672
# Resampled data: [0.65795909 0.90961938 0.32657387 0.83342304 0.6204176  0.22461556
#  0.46624676 0.32560216 0.8723884  0.51345012]
# Resampling indices: [8 9 6 9 8 6 7 6 9 7]
# Selected resampled particles (before noise):
# Resampled particle 0: [[192.05823957]
#  [ 41.59963335]
#  [ -9.33186342]]
# Resampled particle 1: [[190.84842945]
#  [ 40.92459907]
#  [-10.66160174]]
# Resampled particle 2: [[189.03428115]
#  [ 41.38141698]
#  [-11.60282759]]
# Resampled particle 3: [[190.84842945]
#  [ 40.92459907]
#  [-10.66160174]]
# Resampled particle 4: [[192.05823957]
#  [ 41.59963335]
#  [ -9.33186342]]
# Resampled particle 5: [[189.03428115]
#  [ 41.38141698]
#  [-11.60282759]]
# Resampled particle 6: [[189.87326421]
#  [ 42.2711499 ]
#  [ -9.11100249]]
# Resampled particle 7: [[189.03428115]
#  [ 41.38141698]
#  [-11.60282759]]
# Resampled particle 8: [[190.84842945]
#  [ 40.92459907]
#  [-10.66160174]]
# Resampled particle 9: [[189.87326421]
#  [ 42.2711499 ]
#  [ -9.11100249]]
# Updated particle 0: [[389.5994689 ]
#  [ 84.57113873]
#  [-17.59794687]]
# Updated particle 1: [[377.02303986]
#  [ 81.34905759]
#  [-16.16488766]]
# Updated particle 2: [[376.69920539]
#  [ 81.7107614 ]
#  [-21.6644142 ]]
# Updated particle 3: [[376.67255563]
#  [ 81.40269617]
#  [-19.17507151]]
# Updated particle 4: [[383.94288732]
#  [ 81.58678429]
#  [-17.8239637 ]]
# Updated particle 5: [[378.26559573]
#  [ 81.83920989]
#  [-22.12164863]]
# Updated particle 6: [[380.77472486]
#  [ 84.3767605 ]
#  [-17.36814481]]
# Updated particle 7: [[373.86110271]
#  [ 82.57924975]
#  [-22.60719065]]
# Updated particle 8: [[385.54069679]
#  [ 82.37138543]
#  [-18.83972774]]
# Updated particle 9: [[374.30859158]
#  [ 86.88788352]
#  [-18.99998734]]
# Final particles after resampling and noise addition:
# Particle 0: [[389.5994689 ]
#  [ 84.57113873]
#  [-17.59794687]]
# Particle 1: [[377.02303986]
#  [ 81.34905759]
#  [-16.16488766]]
# Particle 2: [[376.69920539]
#  [ 81.7107614 ]
#  [-21.6644142 ]]
# Particle 3: [[376.67255563]
#  [ 81.40269617]
#  [-19.17507151]]
# Particle 4: [[383.94288732]
#  [ 81.58678429]
#  [-17.8239637 ]]
# Particle 5: [[378.26559573]
#  [ 81.83920989]
#  [-22.12164863]]
# Particle 6: [[380.77472486]
#  [ 84.3767605 ]
#  [-17.36814481]]
# Particle 7: [[373.86110271]
#  [ 82.57924975]
#  [-22.60719065]]
# Particle 8: [[385.54069679]
#  [ 82.37138543]
#  [-18.83972774]]
# Particle 9: [[374.30859158]
#  [ 86.88788352]
#  [-18.99998734]]
# entered reSampling particles at time step 10
# weight length 10
# particle length 10
# entered filterParticles at time step 10
# weight length 10
# particle length 10
# we are at time step 11
# entered progress particles at time step 11
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 11
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.017181520909368298
# Resampled data: [0.52374877 0.07968887 0.55688163 0.1849384  0.32775914 0.55888904
#  0.71800601 0.63449477 0.73272555 0.63959274]
# Resampling indices: [7 4 7 5 6 7 8 7 8 7]
# Selected resampled particles (before noise):
# Resampled particle 0: [[292.22003789]
#  [ 53.45835719]
#  [-29.63127952]]
# Resampled particle 1: [[287.83721127]
#  [ 55.04738   ]
#  [-27.35840839]]
# Resampled particle 2: [[292.22003789]
#  [ 53.45835719]
#  [-29.63127952]]
# Resampled particle 3: [[290.81019616]
#  [ 56.957595  ]
#  [-31.00367808]]
# Resampled particle 4: [[289.49781241]
#  [ 55.77574847]
#  [-27.84026299]]
# Resampled particle 5: [[292.22003789]
#  [ 53.45835719]
#  [-29.63127952]]
# Resampled particle 6: [[288.73564272]
#  [ 55.89522004]
#  [-28.02117751]]
# Resampled particle 7: [[292.22003789]
#  [ 53.45835719]
#  [-29.63127952]]
# Resampled particle 8: [[288.73564272]
#  [ 55.89522004]
#  [-28.02117751]]
# Resampled particle 9: [[292.22003789]
#  [ 53.45835719]
#  [-29.63127952]]
# Updated particle 0: [[582.54084435]
#  [108.12322996]
#  [-62.96569274]]
# Updated particle 1: [[573.58367198]
#  [108.62459813]
#  [-50.21046734]]
# Updated particle 2: [[590.65938319]
#  [104.24810882]
#  [-59.74034619]]
# Updated particle 3: [[580.6221913 ]
#  [114.8904267 ]
#  [-63.06940124]]
# Updated particle 4: [[579.32462639]
#  [105.23540635]
#  [-54.37447286]]
# Updated particle 5: [[586.68400121]
#  [ 99.65740656]
#  [-54.65531754]]
# Updated particle 6: [[585.77917012]
#  [104.62906782]
#  [-50.40651728]]
# Updated particle 7: [[580.32370813]
#  [110.31943362]
#  [-63.49925564]]
# Updated particle 8: [[578.5979345 ]
#  [113.09907765]
#  [-56.16862846]]
# Updated particle 9: [[585.14208928]
#  [110.46884023]
#  [-65.51864585]]
# Final particles after resampling and noise addition:
# Particle 0: [[582.54084435]
#  [108.12322996]
#  [-62.96569274]]
# Particle 1: [[573.58367198]
#  [108.62459813]
#  [-50.21046734]]
# Particle 2: [[590.65938319]
#  [104.24810882]
#  [-59.74034619]]
# Particle 3: [[580.6221913 ]
#  [114.8904267 ]
#  [-63.06940124]]
# Particle 4: [[579.32462639]
#  [105.23540635]
#  [-54.37447286]]
# Particle 5: [[586.68400121]
#  [ 99.65740656]
#  [-54.65531754]]
# Particle 6: [[585.77917012]
#  [104.62906782]
#  [-50.40651728]]
# Particle 7: [[580.32370813]
#  [110.31943362]
#  [-63.49925564]]
# Particle 8: [[578.5979345 ]
#  [113.09907765]
#  [-56.16862846]]
# Particle 9: [[585.14208928]
#  [110.46884023]
#  [-65.51864585]]
# entered reSampling particles at time step 11
# weight length 10
# particle length 10
# entered filterParticles at time step 11
# weight length 10
# particle length 10
# we are at time step 12
# entered progress particles at time step 12
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 12
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.02052342651334457
# Resampled data: [0.29794303 0.65460063 0.94281016 0.4109098  0.34628911 0.72893715
#  0.61293783 0.88462923 0.91730891 0.8478608 ]
# Resampling indices: [6 8 9 6 6 8 7 9 9 9]
# Selected resampled particles (before noise):
# Resampled particle 0: [[432.23181049]
#  [ 88.78778389]
#  [-31.11215348]]
# Resampled particle 1: [[431.42412678]
#  [ 89.22333565]
#  [-29.83560098]]
# Resampled particle 2: [[430.85842375]
#  [ 90.51991954]
#  [-32.14355694]]
# Resampled particle 3: [[432.23181049]
#  [ 88.78778389]
#  [-31.11215348]]
# Resampled particle 4: [[432.23181049]
#  [ 88.78778389]
#  [-31.11215348]]
# Resampled particle 5: [[431.42412678]
#  [ 89.22333565]
#  [-29.83560098]]
# Resampled particle 6: [[430.08447781]
#  [ 91.02240542]
#  [-30.70889744]]
# Resampled particle 7: [[430.85842375]
#  [ 90.51991954]
#  [-32.14355694]]
# Resampled particle 8: [[430.85842375]
#  [ 90.51991954]
#  [-32.14355694]]
# Resampled particle 9: [[430.85842375]
#  [ 90.51991954]
#  [-32.14355694]]
# Updated particle 0: [[868.083532  ]
#  [182.04879282]
#  [-66.28900472]]
# Updated particle 1: [[860.65198349]
#  [178.44626316]
#  [-62.41315683]]
# Updated particle 2: [[865.07810512]
#  [179.21678891]
#  [-62.99143086]]
# Updated particle 3: [[864.65549194]
#  [177.41883334]
#  [-57.10217039]]
# Updated particle 4: [[864.85038923]
#  [178.93545345]
#  [-60.73135433]]
# Updated particle 5: [[866.03407851]
#  [177.09726289]
#  [-59.40667294]]
# Updated particle 6: [[856.79674565]
#  [182.04722807]
#  [-61.48708648]]
# Updated particle 7: [[863.52767431]
#  [184.19885792]
#  [-67.08542503]]
# Updated particle 8: [[863.2597126 ]
#  [185.52660039]
#  [-62.73009446]]
# Updated particle 9: [[858.78911192]
#  [185.14623621]
#  [-65.90315396]]
# Final particles after resampling and noise addition:
# Particle 0: [[868.083532  ]
#  [182.04879282]
#  [-66.28900472]]
# Particle 1: [[860.65198349]
#  [178.44626316]
#  [-62.41315683]]
# Particle 2: [[865.07810512]
#  [179.21678891]
#  [-62.99143086]]
# Particle 3: [[864.65549194]
#  [177.41883334]
#  [-57.10217039]]
# Particle 4: [[864.85038923]
#  [178.93545345]
#  [-60.73135433]]
# Particle 5: [[866.03407851]
#  [177.09726289]
#  [-59.40667294]]
# Particle 6: [[856.79674565]
#  [182.04722807]
#  [-61.48708648]]
# Particle 7: [[863.52767431]
#  [184.19885792]
#  [-67.08542503]]
# Particle 8: [[863.2597126 ]
#  [185.52660039]
#  [-62.73009446]]
# Particle 9: [[858.78911192]
#  [185.14623621]
#  [-65.90315396]]
# entered reSampling particles at time step 12
# weight length 10
# particle length 10
# entered filterParticles at time step 12
# weight length 10
# particle length 10
# we are at time step 13
# entered progress particles at time step 13
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 13
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.017199365784705684
# Resampled data: [0.15306069 0.37190463 0.03965202 0.71877236 0.05290247 0.90928826
#  0.6693492  0.80404726 0.83090881 0.67694525]
# Resampling indices: [4 6 4 7 4 9 7 8 8 7]
# Selected resampled particles (before noise):
# Resampled particle 0: [[649.97105264]
#  [147.26603205]
#  [-33.08825289]]
# Resampled particle 1: [[651.64077011]
#  [147.86429516]
#  [-35.36697776]]
# Resampled particle 2: [[649.97105264]
#  [147.26603205]
#  [-33.08825289]]
# Resampled particle 3: [[652.11345731]
#  [147.41982916]
#  [-33.01005622]]
# Resampled particle 4: [[649.97105264]
#  [147.26603205]
#  [-33.08825289]]
# Resampled particle 5: [[651.64628812]
#  [145.33523696]
#  [-33.95075854]]
# Resampled particle 6: [[652.11345731]
#  [147.41982916]
#  [-33.01005622]]
# Resampled particle 7: [[649.20909925]
#  [149.84167403]
#  [-36.21389467]]
# Resampled particle 8: [[649.20909925]
#  [149.84167403]
#  [-36.21389467]]
# Resampled particle 9: [[652.11345731]
#  [147.41982916]
#  [-33.01005622]]
# Updated particle 0: [[1303.36630329]
#  [ 298.17151213]
#  [ -59.66293932]]
# Updated particle 1: [[1303.55995422]
#  [ 293.00770541]
#  [ -72.33578855]]
# Updated particle 2: [[1301.63634361]
#  [ 296.78652376]
#  [ -65.38150477]]
# Updated particle 3: [[1300.5147386 ]
#  [ 293.09689567]
#  [ -62.66168932]]
# Updated particle 4: [[1300.24780832]
#  [ 295.28608533]
#  [ -64.67332092]]
# Updated particle 5: [[1304.23519903]
#  [ 291.03405018]
#  [ -66.85951523]]
# Updated particle 6: [[1304.64078271]
#  [ 295.79870171]
#  [ -67.40928015]]
# Updated particle 7: [[1297.26619995]
#  [ 296.77341188]
#  [ -70.93745633]]
# Updated particle 8: [[1302.40692209]
#  [ 297.38829846]
#  [ -68.30776006]]
# Updated particle 9: [[1304.05420027]
#  [ 293.30242201]
#  [ -62.78008717]]
# Final particles after resampling and noise addition:
# Particle 0: [[1303.36630329]
#  [ 298.17151213]
#  [ -59.66293932]]
# Particle 1: [[1303.55995422]
#  [ 293.00770541]
#  [ -72.33578855]]
# Particle 2: [[1301.63634361]
#  [ 296.78652376]
#  [ -65.38150477]]
# Particle 3: [[1300.5147386 ]
#  [ 293.09689567]
#  [ -62.66168932]]
# Particle 4: [[1300.24780832]
#  [ 295.28608533]
#  [ -64.67332092]]
# Particle 5: [[1304.23519903]
#  [ 291.03405018]
#  [ -66.85951523]]
# Particle 6: [[1304.64078271]
#  [ 295.79870171]
#  [ -67.40928015]]
# Particle 7: [[1297.26619995]
#  [ 296.77341188]
#  [ -70.93745633]]
# Particle 8: [[1302.40692209]
#  [ 297.38829846]
#  [ -68.30776006]]
# Particle 9: [[1304.05420027]
#  [ 293.30242201]
#  [ -62.78008717]]
# entered reSampling particles at time step 13
# weight length 10
# particle length 10
# entered filterParticles at time step 13
# weight length 10
# particle length 10
# we are at time step 14
# entered progress particles at time step 14
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 14
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.021546528088089704
# Resampled data: [0.76161805 0.05353145 0.01483532 0.77607145 0.25856594 0.49192026
#  0.0634161  0.15473209 0.3773985  0.54495554]
# Resampling indices: [8 5 5 8 6 7 5 5 7 7]
# Selected resampled particles (before noise):
# Resampled particle 0: [[971.60594691]
#  [257.85097427]
#  [-45.84781255]]
# Resampled particle 1: [[968.90415478]
#  [258.2484202 ]
#  [-43.87919817]]
# Resampled particle 2: [[968.90415478]
#  [258.2484202 ]
#  [-43.87919817]]
# Resampled particle 3: [[971.60594691]
#  [257.85097427]
#  [-45.84781255]]
# Resampled particle 4: [[967.66790908]
#  [255.48348659]
#  [-42.48174074]]
# Resampled particle 5: [[968.87492638]
#  [256.43221589]
#  [-44.36846374]]
# Resampled particle 6: [[968.90415478]
#  [258.2484202 ]
#  [-43.87919817]]
# Resampled particle 7: [[968.90415478]
#  [258.2484202 ]
#  [-43.87919817]]
# Resampled particle 8: [[968.87492638]
#  [256.43221589]
#  [-44.36846374]]
# Resampled particle 9: [[968.87492638]
#  [256.43221589]
#  [-44.36846374]]
# Updated particle 0: [[1943.26948654]
#  [ 517.54594287]
#  [ -94.50715654]]
# Updated particle 1: [[1940.63549056]
#  [ 517.63236848]
#  [ -85.53111871]]
# Updated particle 2: [[1942.980334  ]
#  [ 518.63158919]
#  [ -84.42638318]]
# Updated particle 3: [[1941.65753552]
#  [ 513.88130398]
#  [ -95.05108635]]
# Updated particle 4: [[1934.08096341]
#  [ 505.85957508]
#  [ -85.94827355]]
# Updated particle 5: [[1940.56089185]
#  [ 512.50271954]
#  [ -92.26282978]]
# Updated particle 6: [[1941.42527315]
#  [ 516.93101982]
#  [ -86.08254776]]
# Updated particle 7: [[1938.0994922 ]
#  [ 512.95926622]
#  [ -83.85739641]]
# Updated particle 8: [[1932.06896255]
#  [ 508.44235738]
#  [ -90.52392612]]
# Updated particle 9: [[1938.30546881]
#  [ 507.95514266]
#  [ -92.7188002 ]]
# Final particles after resampling and noise addition:
# Particle 0: [[1943.26948654]
#  [ 517.54594287]
#  [ -94.50715654]]
# Particle 1: [[1940.63549056]
#  [ 517.63236848]
#  [ -85.53111871]]
# Particle 2: [[1942.980334  ]
#  [ 518.63158919]
#  [ -84.42638318]]
# Particle 3: [[1941.65753552]
#  [ 513.88130398]
#  [ -95.05108635]]
# Particle 4: [[1934.08096341]
#  [ 505.85957508]
#  [ -85.94827355]]
# Particle 5: [[1940.56089185]
#  [ 512.50271954]
#  [ -92.26282978]]
# Particle 6: [[1941.42527315]
#  [ 516.93101982]
#  [ -86.08254776]]
# Particle 7: [[1938.0994922 ]
#  [ 512.95926622]
#  [ -83.85739641]]
# Particle 8: [[1932.06896255]
#  [ 508.44235738]
#  [ -90.52392612]]
# Particle 9: [[1938.30546881]
#  [ 507.95514266]
#  [ -92.7188002 ]]
# entered reSampling particles at time step 14
# weight length 10
# particle length 10
# entered filterParticles at time step 14
# weight length 10
# particle length 10
# we are at time step 15
# entered progress particles at time step 15
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 15
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.017728644085650138
# Resampled data: [0.44107595 0.1215966  0.035934   0.54609905 0.76694848 0.89104657
#  0.06733844 0.05743072 0.95970407 0.76101713]
# Resampling indices: [6 4 4 7 8 9 4 4 9 8]
# Selected resampled particles (before noise):
# Resampled particle 0: [[1454.14291493]
#  [ 455.74049108]
#  [ -50.27674199]]
# Resampled particle 1: [[1455.46565637]
#  [ 458.55173911]
#  [ -50.30749893]]
# Resampled particle 2: [[1455.46565637]
#  [ 458.55173911]
#  [ -50.30749893]]
# Resampled particle 3: [[1452.69142193]
#  [ 456.39929224]
#  [ -50.90760553]]
# Resampled particle 4: [[1456.29012201]
#  [ 456.5655515 ]
#  [ -49.28212424]]
# Resampled particle 5: [[1453.13831565]
#  [ 455.49522602]
#  [ -50.30791058]]
# Resampled particle 6: [[1455.46565637]
#  [ 458.55173911]
#  [ -50.30749893]]
# Resampled particle 7: [[1455.46565637]
#  [ 458.55173911]
#  [ -50.30749893]]
# Resampled particle 8: [[1453.13831565]
#  [ 455.49522602]
#  [ -50.30791058]]
# Resampled particle 9: [[1456.29012201]
#  [ 456.5655515 ]
#  [ -49.28212424]]
# Updated particle 0: [[2909.90086868]
#  [ 914.84111891]
#  [ -97.83355782]]
# Updated particle 1: [[2910.57297181]
#  [ 917.23071478]
#  [-101.29874221]]
# Updated particle 2: [[2915.47494854]
#  [ 917.70417493]
#  [-101.2857546 ]]
# Updated particle 3: [[2905.23443368]
#  [ 913.04857125]
#  [-103.48815206]]
# Updated particle 4: [[2910.23405607]
#  [ 916.10522169]
#  [ -93.36643045]]
# Updated particle 5: [[2900.02245053]
#  [ 911.61682461]
#  [-107.11803514]]
# Updated particle 6: [[2905.69328771]
#  [ 912.48942878]
#  [-101.69797787]]
# Updated particle 7: [[2908.19119057]
#  [ 919.74369251]
#  [-101.21504498]]
# Updated particle 8: [[2903.36752722]
#  [ 913.14642614]
#  [-100.77662382]]
# Updated particle 9: [[2914.99771939]
#  [ 908.28726459]
#  [ -98.93173455]]
# Final particles after resampling and noise addition:
# Particle 0: [[2909.90086868]
#  [ 914.84111891]
#  [ -97.83355782]]
# Particle 1: [[2910.57297181]
#  [ 917.23071478]
#  [-101.29874221]]
# Particle 2: [[2915.47494854]
#  [ 917.70417493]
#  [-101.2857546 ]]
# Particle 3: [[2905.23443368]
#  [ 913.04857125]
#  [-103.48815206]]
# Particle 4: [[2910.23405607]
#  [ 916.10522169]
#  [ -93.36643045]]
# Particle 5: [[2900.02245053]
#  [ 911.61682461]
#  [-107.11803514]]
# Particle 6: [[2905.69328771]
#  [ 912.48942878]
#  [-101.69797787]]
# Particle 7: [[2908.19119057]
#  [ 919.74369251]
#  [-101.21504498]]
# Particle 8: [[2903.36752722]
#  [ 913.14642614]
#  [-100.77662382]]
# Particle 9: [[2914.99771939]
#  [ 908.28726459]
#  [ -98.93173455]]
# entered reSampling particles at time step 15
# weight length 10
# particle length 10
# entered filterParticles at time step 15
# weight length 10
# particle length 10
# we are at time step 16
# entered progress particles at time step 16
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 16
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.020181189555328913
# Resampled data: [0.64963963 0.94001534 0.00965729 0.85197645 0.51900225 0.54046554
#  0.57916636 0.78551761 0.13956237 0.19166802]
# Resampling indices: [8 9 5 9 7 7 7 8 5 6]
# Selected resampled particles (before noise):
# Resampled particle 0: [[2183.91126036]
#  [ 804.83596017]
#  [ -58.48114687]]
# Resampled particle 1: [[2185.65569887]
#  [ 806.86931869]
#  [ -58.64477199]]
# Resampled particle 2: [[2183.0698424 ]
#  [ 807.58114742]
#  [ -60.33138107]]
# Resampled particle 3: [[2185.65569887]
#  [ 806.86931869]
#  [ -58.64477199]]
# Resampled particle 4: [[2187.04136518]
#  [ 807.40680775]
#  [ -59.0731319 ]]
# Resampled particle 5: [[2187.04136518]
#  [ 807.40680775]
#  [ -59.0731319 ]]
# Resampled particle 6: [[2187.04136518]
#  [ 807.40680775]
#  [ -59.0731319 ]]
# Resampled particle 7: [[2183.91126036]
#  [ 804.83596017]
#  [ -58.48114687]]
# Resampled particle 8: [[2183.0698424 ]
#  [ 807.58114742]
#  [ -60.33138107]]
# Resampled particle 9: [[2183.60827888]
#  [ 807.96634389]
#  [ -59.05300889]]
# Updated particle 0: [[4370.07326753]
#  [1610.81908877]
#  [-114.78642083]]
# Updated particle 1: [[4367.5262669 ]
#  [1611.48043586]
#  [-122.41359108]]
# Updated particle 2: [[4370.34170515]
#  [1613.89366101]
#  [-117.47936808]]
# Updated particle 3: [[4372.05334289]
#  [1613.97078579]
#  [-112.82769222]]
# Updated particle 4: [[4373.63339181]
#  [1609.7864594 ]
#  [-117.05217148]]
# Updated particle 5: [[4380.00509789]
#  [1615.08586418]
#  [-119.18048789]]
# Updated particle 6: [[4371.83983993]
#  [1615.53515142]
#  [-120.75339754]]
# Updated particle 7: [[4370.54871928]
#  [1610.25490027]
#  [-114.58854792]]
# Updated particle 8: [[4362.89185007]
#  [1617.0878784 ]
#  [-117.10180841]]
# Updated particle 9: [[4370.7461855 ]
#  [1616.6536004 ]
#  [-117.00696159]]
# Final particles after resampling and noise addition:
# Particle 0: [[4370.07326753]
#  [1610.81908877]
#  [-114.78642083]]
# Particle 1: [[4367.5262669 ]
#  [1611.48043586]
#  [-122.41359108]]
# Particle 2: [[4370.34170515]
#  [1613.89366101]
#  [-117.47936808]]
# Particle 3: [[4372.05334289]
#  [1613.97078579]
#  [-112.82769222]]
# Particle 4: [[4373.63339181]
#  [1609.7864594 ]
#  [-117.05217148]]
# Particle 5: [[4380.00509789]
#  [1615.08586418]
#  [-119.18048789]]
# Particle 6: [[4371.83983993]
#  [1615.53515142]
#  [-120.75339754]]
# Particle 7: [[4370.54871928]
#  [1610.25490027]
#  [-114.58854792]]
# Particle 8: [[4362.89185007]
#  [1617.0878784 ]
#  [-117.10180841]]
# Particle 9: [[4370.7461855 ]
#  [1616.6536004 ]
#  [-117.00696159]]
# entered reSampling particles at time step 16
# weight length 10
# particle length 10
# entered filterParticles at time step 16
# weight length 10
# particle length 10
# we are at time step 17
# entered progress particles at time step 17
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 17
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.01719962649000481
# Resampled data: [0.66876521 0.76280147 0.63379091 0.73040181 0.46533776 0.23291918
#  0.1299276  0.29403851 0.2971569  0.573524  ]
# Resampling indices: [8 8 7 8 6 5 5 5 5 7]
# Selected resampled particles (before noise):
# Resampled particle 0: [[3271.81670954]
#  [1405.05782338]
#  [ -77.2807295 ]]
# Resampled particle 1: [[3271.81670954]
#  [1405.05782338]
#  [ -77.2807295 ]]
# Resampled particle 2: [[3272.17034159]
#  [1405.4800266 ]
#  [ -78.90558314]]
# Resampled particle 3: [[3271.81670954]
#  [1405.05782338]
#  [ -77.2807295 ]]
# Resampled particle 4: [[3272.94875626]
#  [1402.17752952]
#  [ -78.71226088]]
# Resampled particle 5: [[3272.13088375]
#  [1404.10769527]
#  [ -77.2126904 ]]
# Resampled particle 6: [[3272.13088375]
#  [1404.10769527]
#  [ -77.2126904 ]]
# Resampled particle 7: [[3272.13088375]
#  [1404.10769527]
#  [ -77.2126904 ]]
# Resampled particle 8: [[3272.13088375]
#  [1404.10769527]
#  [ -77.2126904 ]]
# Resampled particle 9: [[3272.17034159]
#  [1405.4800266 ]
#  [ -78.90558314]]
# Updated particle 0: [[6546.19764198]
#  [2807.98197681]
#  [-155.07310345]]
# Updated particle 1: [[6541.94603394]
#  [2806.87599383]
#  [-153.11874319]]
# Updated particle 2: [[6548.17207956]
#  [2809.84338885]
#  [-153.11801499]]
# Updated particle 3: [[6541.66527723]
#  [2810.73056112]
#  [-151.80815457]]
# Updated particle 4: [[6547.06821435]
#  [2804.27125189]
#  [-160.51985824]]
# Updated particle 5: [[6546.57326044]
#  [2810.75137667]
#  [-156.2942506 ]]
# Updated particle 6: [[6542.39602231]
#  [2811.30229978]
#  [-154.23454865]]
# Updated particle 7: [[6548.33481003]
#  [2807.21234266]
#  [-149.44726162]]
# Updated particle 8: [[6541.77724834]
#  [2803.00446936]
#  [-159.70333783]]
# Updated particle 9: [[6543.61908553]
#  [2811.50176837]
#  [-153.08319048]]
# Final particles after resampling and noise addition:
# Particle 0: [[6546.19764198]
#  [2807.98197681]
#  [-155.07310345]]
# Particle 1: [[6541.94603394]
#  [2806.87599383]
#  [-153.11874319]]
# Particle 2: [[6548.17207956]
#  [2809.84338885]
#  [-153.11801499]]
# Particle 3: [[6541.66527723]
#  [2810.73056112]
#  [-151.80815457]]
# Particle 4: [[6547.06821435]
#  [2804.27125189]
#  [-160.51985824]]
# Particle 5: [[6546.57326044]
#  [2810.75137667]
#  [-156.2942506 ]]
# Particle 6: [[6542.39602231]
#  [2811.30229978]
#  [-154.23454865]]
# Particle 7: [[6548.33481003]
#  [2807.21234266]
#  [-149.44726162]]
# Particle 8: [[6541.77724834]
#  [2803.00446936]
#  [-159.70333783]]
# Particle 9: [[6543.61908553]
#  [2811.50176837]
#  [-153.08319048]]
# entered reSampling particles at time step 17
# weight length 10
# particle length 10
# entered filterParticles at time step 17
# weight length 10
# particle length 10
# we are at time step 18
# entered progress particles at time step 18
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 18
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.021037566195827063
# Resampled data: [0.67829892 0.33267158 0.85399629 0.1497528  0.38831463 0.73370896
#  0.9433562  0.3694433  0.38448595 0.50804824]
# Resampling indices: [8 6 9 5 6 8 9 6 6 7]
# Selected resampled particles (before noise):
# Resampled particle 0: [[4911.57155612]
#  [2457.09266041]
#  [ -83.94314002]]
# Resampled particle 1: [[4913.1400779 ]
#  [2455.78597561]
#  [ -83.42593133]]
# Resampled particle 2: [[4911.9026281 ]
#  [2454.10436304]
#  [ -83.8471435 ]]
# Resampled particle 3: [[4910.69337754]
#  [2453.50633284]
#  [ -80.59572165]]
# Resampled particle 4: [[4913.1400779 ]
#  [2455.78597561]
#  [ -83.42593133]]
# Resampled particle 5: [[4911.57155612]
#  [2457.09266041]
#  [ -83.94314002]]
# Resampled particle 6: [[4911.9026281 ]
#  [2454.10436304]
#  [ -83.8471435 ]]
# Resampled particle 7: [[4913.1400779 ]
#  [2455.78597561]
#  [ -83.42593133]]
# Resampled particle 8: [[4913.1400779 ]
#  [2455.78597561]
#  [ -83.42593133]]
# Resampled particle 9: [[4911.85756984]
#  [2455.01727444]
#  [ -84.16401131]]
# Updated particle 0: [[9825.11477319]
#  [4914.57707208]
#  [-165.20616569]]
# Updated particle 1: [[9826.98137818]
#  [4910.52807866]
#  [-168.73454376]]
# Updated particle 2: [[9823.03098648]
#  [4905.13495606]
#  [-166.68965936]]
# Updated particle 3: [[9821.56982746]
#  [4910.61455845]
#  [-161.78959384]]
# Updated particle 4: [[9825.91658081]
#  [4908.40811916]
#  [-169.64049242]]
# Updated particle 5: [[9824.94228188]
#  [4911.50726786]
#  [-169.76054369]]
# Updated particle 6: [[9824.24643185]
#  [4903.49916765]
#  [-172.09975857]]
# Updated particle 7: [[9826.19897895]
#  [4914.01756835]
#  [-167.17576375]]
# Updated particle 8: [[9825.74554087]
#  [4913.37140134]
#  [-173.87451252]]
# Updated particle 9: [[9821.92018349]
#  [4911.4050806 ]
#  [-167.91237152]]
# Final particles after resampling and noise addition:
# Particle 0: [[9825.11477319]
#  [4914.57707208]
#  [-165.20616569]]
# Particle 1: [[9826.98137818]
#  [4910.52807866]
#  [-168.73454376]]
# Particle 2: [[9823.03098648]
#  [4905.13495606]
#  [-166.68965936]]
# Particle 3: [[9821.56982746]
#  [4910.61455845]
#  [-161.78959384]]
# Particle 4: [[9825.91658081]
#  [4908.40811916]
#  [-169.64049242]]
# Particle 5: [[9824.94228188]
#  [4911.50726786]
#  [-169.76054369]]
# Particle 6: [[9824.24643185]
#  [4903.49916765]
#  [-172.09975857]]
# Particle 7: [[9826.19897895]
#  [4914.01756835]
#  [-167.17576375]]
# Particle 8: [[9825.74554087]
#  [4913.37140134]
#  [-173.87451252]]
# Particle 9: [[9821.92018349]
#  [4911.4050806 ]
#  [-167.91237152]]
# entered reSampling particles at time step 18
# weight length 10
# particle length 10
# entered filterParticles at time step 18
# weight length 10
# particle length 10
# we are at time step 19
# entered progress particles at time step 19
# weight length 10
# particle length 10
# entered calculateWeights particles at time step 19
# weight length 10
# particle length 10
# Sampling threshold: 6.666666666666667
# Squared weights: 0.017408707397622108
# Resampled data: [0.33124952 0.53068856 0.59343336 0.435441   0.685347   0.66132854
#  0.62877552 0.33056692 0.42823446 0.86762928]
# Resampling indices: [5 6 7 6 7 7 7 5 6 9]
# Selected resampled particles (before noise):
# Resampled particle 0: [[7360.64550588]
#  [4287.14047502]
#  [ -97.25944197]]
# Resampled particle 1: [[7360.81881253]
#  [4286.76745663]
#  [ -99.44453127]]
# Resampled particle 2: [[7359.97934119]
#  [4285.2501523 ]
#  [ -99.53055805]]
# Resampled particle 3: [[7360.81881253]
#  [4286.76745663]
#  [ -99.44453127]]
# Resampled particle 4: [[7359.97934119]
#  [4285.2501523 ]
#  [ -99.53055805]]
# Resampled particle 5: [[7359.97934119]
#  [4285.2501523 ]
#  [ -99.53055805]]
# Resampled particle 6: [[7359.97934119]
#  [4285.2501523 ]
#  [ -99.53055805]]
# Resampled particle 7: [[7360.64550588]
#  [4287.14047502]
#  [ -97.25944197]]
# Resampled particle 8: [[7360.81881253]
#  [4286.76745663]
#  [ -99.44453127]]
# Resampled particle 9: [[7360.99585453]
#  [4286.48784072]
#  [ -98.4868168 ]]
# Updated particle 0: [[14721.85664202]
#  [ 8575.14673224]
#  [ -192.9289349 ]]
# Updated particle 1: [[14719.62092542]
#  [ 8575.61828247]
#  [ -202.1490743 ]]
# Updated particle 2: [[14718.25618825]
#  [ 8569.35949013]
#  [ -198.64345672]]
# Updated particle 3: [[14724.55840306]
#  [ 8572.23319351]
#  [ -200.80220083]]
# Updated particle 4: [[14723.23803028]
#  [ 8566.11705439]
#  [ -200.11467034]]
# Updated particle 5: [[14718.78471609]
#  [ 8566.11940738]
#  [ -201.2295203 ]]
# Updated particle 6: [[14717.24713765]
#  [ 8572.68512431]
#  [ -198.35297207]]
# Updated particle 7: [[14722.44575312]
#  [ 8576.12287535]
#  [ -191.21706834]]
# Updated particle 8: [[14721.18096383]
#  [ 8576.2481648 ]
#  [ -196.36949806]]
# Updated particle 9: [[14721.34555524]
#  [ 8571.13282773]
#  [ -200.6746315 ]]
# Final particles after resampling and noise addition:
# Particle 0: [[14721.85664202]
#  [ 8575.14673224]
#  [ -192.9289349 ]]
# Particle 1: [[14719.62092542]
#  [ 8575.61828247]
#  [ -202.1490743 ]]
# Particle 2: [[14718.25618825]
#  [ 8569.35949013]
#  [ -198.64345672]]
# Particle 3: [[14724.55840306]
#  [ 8572.23319351]
#  [ -200.80220083]]
# Particle 4: [[14723.23803028]
#  [ 8566.11705439]
#  [ -200.11467034]]
# Particle 5: [[14718.78471609]
#  [ 8566.11940738]
#  [ -201.2295203 ]]
# Particle 6: [[14717.24713765]
#  [ 8572.68512431]
#  [ -198.35297207]]
# Particle 7: [[14722.44575312]
#  [ 8576.12287535]
#  [ -191.21706834]]
# Particle 8: [[14721.18096383]
#  [ 8576.2481648 ]
#  [ -196.36949806]]
# Particle 9: [[14721.34555524]
#  [ 8571.13282773]
#  [ -200.6746315 ]]
# entered reSampling particles at time step 19
# weight length 10
# particle length 10
# entered filterParticles at time step 19
# weight length 10
# particle length 10
# C:\Users\vijay\AppData\Local\Temp\ipykernel_11608\3389827480.py:198: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   cdfArray[i] = self.weights[i] + (cdfArray[i - 1] if i > 0 else 0)
# C:\Users\vijay\AppData\Local\Temp\ipykernel_11608\3389827480.py:161: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   newWeights[-(i+1)] = self.weights[sortedIndeces[-(i+1)]] / weights_sum
